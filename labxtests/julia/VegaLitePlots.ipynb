# %%
using VegaLite, VegaDatasets

# %%
p = dataset("cars") |>
       @vlplot(
           :point,
           x=:Horsepower,
           y=:Miles_per_Gallon,
           color=:Origin,
           width=400,
           height=400
       )
# Out:
# @vlplot(
#     width=400,
#     height=400,
#     mark="point",
#     encoding={
#         x={
#             field="Horsepower"
#         },
#         y={
#             field="Miles_per_Gallon"
#         },
#         color={
#             field="Origin"
#         }
#     },
#     data={
#         values=...
#     }
# )
