# %%
using XAM,Plots
plotlyjs()
# Out:
# WebIO._IJuliaInit()
# Plots.PlotlyJSBackend()

# %%
bamName="/Users/james/src/sandbox/benchmarks/samtools/bench3/data/PC-HLA-EG4.bam"
# Out:
# "/Users/james/src/sandbox/benchmarks/samtools/bench3/data/PC-HLA-EG4.bam"

# %%
allquals=Int[]
bamIn = open(BAM.Reader,bamName)
for a in bamIn
    push!(allquals,BAM.mappingquality(a))
end

# %%
length(allquals)
# Out:
# 24848

# %%
Plots.histogram(allquals,nbins=20)

# %%
Plots.histogram(allquals,nbins=40)
